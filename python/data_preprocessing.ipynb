# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# seaborn settings
sns.set_theme()
sns.set_context("poster", font_scale=1.4)

# %matplotlib inline

# %%
# https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
# !ls ./../archive
# Out:
# auto-mpg.data  auto-mpg.names

# %%
data_filepath = './../archive/auto-mpg.data'

# %%
df = pd.read_csv(data_filepath, delim_whitespace=True, header=None, 
                 names=['mpg', 'cylinders', 'displacement', 'horsepower', 
                        'weight', 'acceleration', 'model_year', 'origin', 'car_name'])

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap="RdBu")
# Out:
# <AxesSubplot:>

# %%
hist = df['mpg'].hist(bins=35, figsize=(20, 10))

# %%
df['mpg'].mean(), df['mpg'].var(), df['mpg'].skew()
# Out:
# (23.514572864321615, 61.089610774274405, 0.45706634399491913)

# %%
df.plot.scatter('cylinders', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
df.plot.scatter('displacement', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
df.plot.scatter('horsepower', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
df.plot.scatter('weight', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
df.plot.scatter('acceleration', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
df.plot.scatter('origin', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
df.plot.scatter('model_year', 'mpg', figsize=(20, 10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>
